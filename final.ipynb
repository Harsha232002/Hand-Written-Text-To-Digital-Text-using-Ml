# %%
from platform import python_version

print(python_version())
# Out:
# 3.10.7

# %%
import pytesseract
import cv2
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img=mpimg.imread('self_lines/selfMade_126.png')
plt.figure(figsize=(10,10))
plt.imshow(img, cmap ='gray')

# %%
img=cv2.imread('self_lines/selfMade_126.png')
text = pytesseract.image_to_string(img)
print(text)
# Out:
# been around for many years, but they were not

# %%
img=mpimg.imread('data/672/sample-1.jpeg')
plt.figure(figsize=(5,5))
plt.imshow(img, cmap ='gray')

# %%
img=cv2.imread('data/672/sample-1.jpeg')
text = pytesseract.image_to_string(img)
print(text)
# Out:
# Batch —|6—
# P HARSHA

# %%
text_file = open("data.txt", "w", encoding="utf-8")

#write string to file
text_file.write(text)

#close file
text_file.close()

# %%
img=mpimg.imread('data/022/a02-004.png')
plt.figure(figsize=(5,5))
plt.imshow(img, cmap ='gray')

# %%
img=cv2.imread('data/022/a02-004.png')
text = pytesseract.image_to_string(img)
print(text)
# Out:
# Sentence Database A02-004
#
# So the idea of a personal mission by the Prime Minister to Paris was dropped. Instead
# Mr. Macmillan will rely on a hand-picked team under the leadership of Sir Pierson
# Dixon, Britain’s Ambassador to France, to back Mr. Edward Heath, Lord Privy Seal,
# who is charged with the conduct of negotiations with the Six. At the same time the
# Prime Minister has offered Commonwealth Governments every facility possible to
# safeguard their interests.
#
# 0 the |dea of Peysenal NISS8i1o4 by
#
# the Parme Chiniséer 10 [GS Vee derpp ed
# Instead Ly, (Pac rns leet itl rely 4 qY
#
# hond “piel al Teem unedle- the Deud2-Sh yf aL
# Cr Presen Dixon [Sor tarn’s, climbs adey te
# Pie re CA eheek Fr Cd Mand Heath Cord
# Privy Seed WhO 18 cb org el % th the C nlyet
# 0 1 epotialic 198 WIth LES! x Me 142 Seme
# fime the Parma SH ni'slse has fer ed.
#
# COMM eh rca lh 2VAY facil ty Pa $9, 4 /eTo-
#
# S oLogegad th G7 Inleests
#
# Name:

# %%
text_file = open("data1.txt", "w", encoding="utf-8")

#write string to file
text_file.write(text)

#close file
text_file.close()
